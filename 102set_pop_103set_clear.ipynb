# %% [markdown]
# <a href="https://colab.research.google.com/github/kjh0618/Homework/blob/main/102set_pop_103set_clear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = {'사과', '배', '오렌지', '수박'}
choise = fruits.pop()
print(f'++ 추출한 요소: {choise}\n++ fruits: {fruits}')

for _ in range(len(fruits)):
  choise = fruits.pop()
  print(f'++ 추출한 요소: {choise}\n++ fruits: {fruits}')
choise = fruits.pop()

set1 = set('abradacabra')
set2 = set('arirangsong')
set1 &= set2
set2.clear()
print(f'set1={set1}, set2={set2}')
# Out:
# ++ 추출한 요소: 수박
# ++ fruits: {'사과', '오렌지', '배'}
# ++ 추출한 요소: 사과
# ++ fruits: {'오렌지', '배'}
# ++ 추출한 요소: 오렌지
# ++ fruits: {'배'}
# ++ 추출한 요소: 배
# ++ fruits: set()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3524874195.py in <cell line: 0>()
#       6   choise = fruits.pop()
#       7   print(f'++ 추출한 요소: {choise}\n++ fruits: {fruits}')
# ----> 8 choise = fruits.pop()
#       9
#      10 set1 = set('abradacabra')
#
# KeyError: 'pop from an empty set'
