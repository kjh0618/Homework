# %% [markdown]
# <a href="https://colab.research.google.com/github/kjh0618/Homework/blob/main/98set_99set_add.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1 = set('abradacabra')
set2 = set('abbreviation')

ret = set1 | set2
print(ret)

ret = set1 & set2
print(ret)

ret = set1 - set2
print(ret)

ret = set1 ^ set2
print(ret)

ret = set1 <= set2
print(ret)

fruits = {'사과', '배', '오렌지', '수박'}
fruits.add('딸기')
print(fruits)

fruits.add('배')
print(fruits)
# Out:
# {'c', 'd', 'b', 'a', 'i', 'n', 'o', 'e', 'r', 't', 'v'}
# {'b', 'r', 'a'}
# {'c', 'd'}
# {'c', 'd', 'i', 'n', 'o', 'e', 't', 'v'}
# False
# {'수박', '배', '사과', '오렌지', '딸기'}
# {'수박', '배', '사과', '오렌지', '딸기'}
